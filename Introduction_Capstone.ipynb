# %% [markdown]
# # 1. Introduction

# %% [markdown]
# ##### Car accidents occur nearly everywhere and unfortunately cause lots of damage and in some cases fatalities.
# In this project, I will try to understand the various causes of road accidents which will in turn give insight into how to avoid them. Furthermore, I will create a model to try to predict accident severity based on several features, this can allow us to deploy this model by creating an app integrated on maps that notifies drivers about accidents their periphery and how severe the accident is.
# I will first explore the data, then c
